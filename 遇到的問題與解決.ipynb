# %% [markdown]
# #### 在做 Hidden Markov model 時，要 install tensorflow_destribution 時報錯:
# ![如圖](data:image/png;base64,...)

# %% [markdown]
# #### 就照著上面的指令到 cmd 安裝相關套件就解決問題了。(我沒有在虛擬環境中安裝):
# ![如圖](data:image/png;base64,...)
